# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# Name: Praveen P
# Profession: Management Student

# %% [markdown]
# I want to enroll in Data Science becuase my aim in life is to become a Data Scientist and serve in IBM in future!

# %% [markdown]
# The Next line code will Depict the python code of "Hello Everyone"

# %%
print("Hello Everyone")
# Out:
# Hello Everyone

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
